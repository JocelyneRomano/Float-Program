# %% [markdown]
# ## Analysis of Salinity vs. Depth of the Southern Ocean using SOCCOM Floats
#
# All float data was saved from the following website: https://soccompu.princeton.edu/www/index.html (High res, MLR, NETCDF)
# * There are three different formats to download (LIAR, CANYON, MLR) each calculate DIC,pCO2 diffrently

# %% [markdown]
# # Imports

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import argopy
import glob
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
import pandas as pd
import glob 
import cartopy
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.shapereader as shpreader
import cartopy.io.img_tiles as cimgt
import cartopy.mpl.geoaxes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# %matplotlib inline

# %%
path='/Users/Jocelyne/Desktop/Floats/'
files=glob.glob(path+'*.nc')
files[0]
# Out:
# '/Users/Jocelyne/Desktop/Floats/5904675_HRQC.nc'

# %% [markdown]
# ## Longtitdinal Bins of the S.O
#
# * At every 30 degrees lon, a Longtitdunal bin was created to house the various floats that are in that particular area

# %% [markdown]
# ## Bin 1 (0°-30°)

# %%
Bin1_pH=[]
Bin1_Salinity=[]
Bin1_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=0 and ds.Lon[ii] <=30:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin1_pH=np.append(Bin1_pH,ds.pHinsitu.values[ii,iii])
                    Bin1_Salinity=np.append(Bin1_Salinity,ds.Salinity.values[ii,iii])
                    Bin1_Depth=np.append(Bin1_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Plot
plt.scatter(Bin1_Salinity,Bin1_Depth, c=Bin1_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 1 Salinity vs. Depth',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin1 Salinity vs. Depth.pdf')
# Out:
# <ipython-input-51-632c263cfa16>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 2 (30°-60°)

# %%
Bin2_pH=[]
Bin2_Salinity=[]
Bin2_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=30 and ds.Lon[ii] <=60:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin2_pH=np.append(Bin2_pH,ds.pHinsitu.values[ii,iii])
                    Bin2_Salinity=np.append(Bin2_Salinity,ds.Salinity.values[ii,iii])
                    Bin2_Depth=np.append(Bin2_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin2_Salinity,Bin2_Depth, c=Bin2_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 2 Salinity [pss] (30°-60°)',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 2 Salinity vs. Depth (30-60).pdf', dpi=600)
# Out:
# <ipython-input-22-11f8f7dd0a6d>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 3 (60°-90°)

# %%
Bin3_pH=[]
Bin3_Salinity=[]
Bin3_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=60 and ds.Lon[ii] <=90:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin3_pH=np.append(Bin3_pH,ds.pHinsitu.values[ii,iii])
                    Bin3_Salinity=np.append(Bin3_Salinity,ds.Salinity.values[ii,iii])
                    Bin3_Depth=np.append(Bin3_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin3_Salinity,Bin3_Depth, c=Bin3_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 3 Salinity vs. Depth',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 3 Salinity vs. Depth.pdf')
# Out:
# <ipython-input-61-17575b19f974>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 4 (90°-120°)

# %%
Bin4_pH=[]
Bin4_Salinity=[]
Bin4_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=90 and ds.Lon[ii] <=120:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin4_pH=np.append(Bin4_pH,ds.pHinsitu.values[ii,iii])
                    Bin4_Salinity=np.append(Bin4_Salinity,ds.Salinity.values[ii,iii])
                    Bin4_Depth=np.append(Bin4_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes',labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin4_Salinity,Bin4_Depth, c=Bin4_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 4 Salinity [pss] (90°-120°)',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 4 Salinity vs. Depth (90-120).pdf', dpi=600)
# Out:
# <ipython-input-21-4b42bc9d288d>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 5 (120°-150°)

# %%
Bin5_pH=[]
Bin5_Salinity=[]
Bin5_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=120 and ds.Lon[ii] <=150:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin5_pH=np.append(Bin5_pH,ds.pHinsitu.values[ii,iii])
                    Bin5_Salinity=np.append(Bin5_Salinity,ds.Salinity.values[ii,iii])
                    Bin5_Depth=np.append(Bin5_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes',labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin5_Salinity,Bin5_Depth,c=Bin5_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin5 Salinity',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 5 Salinity vs. Depth.pdf')
# Out:
# <ipython-input-74-ab5a1e08a069>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 6 (150°-180°)

# %%
Bin6_pH=[]
Bin6_Salinity=[]
Bin6_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=150 and ds.Lon[ii] <=180:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin6_pH=np.append(Bin6_pH,ds.pHinsitu.values[ii,iii])
                    Bin6_Salinity=np.append(Bin6_Salinity,ds.Salinity.values[ii,iii])
                    Bin6_Depth=np.append(Bin6_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin6_Salinity,Bin6_Depth, c=Bin6_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 6 Salinity [pss] (150°-180°)',fontweight="bold")
plt.xlim(33,35)
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)
plt.clim(33,35)

#Save figure
plt.savefig('Bin 6 Salinity vs. Depth (150-180).pdf', dpi=600)
# Out:
# <ipython-input-26-0c88bf35dc8e>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 7 (180°-210°)

# %%
Bin7_pH=[]
Bin7_Salinity=[]
Bin7_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=180 and ds.Lon[ii] <=210:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin7_pH=np.append(Bin7_pH,ds.pHinsitu.values[ii,iii])
                    Bin7_Salinity=np.append(Bin7_Salinity,ds.Salinity.values[ii,iii])
                    Bin7_Depth=np.append(Bin7_Depth,ds.Salinity.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin7_Salinity,Bin7_Depth, c=Bin7_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 7 Salinity vs. Depth',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 7 Salinity vs. Depth.pdf')
# Out:
# <ipython-input-81-96b1cc903e4b>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 8 (210°-240°)

# %%
Bin8_pH=[]
Bin8_Salinity=[]
Bin8_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=210 and ds.Lon[ii] <=240:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin8_pH=np.append(Bin8_pH,ds.pHinsitu.values[ii,iii])
                    Bin8_Salinity=np.append(Bin8_Salinity,ds.Salinity.values[ii,iii])
                    Bin8_Depth=np.append(Bin8_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin8_Salinity,Bin8_Depth, c=Bin8_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 8 Salinity [pss] (210°-240°)',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 8 Salinity vs. Depth (210-240).pdf', dpi=600)
# Out:
# <ipython-input-18-4d4b07dc09d3>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 9 (240°-270°)

# %%
Bin9_pH=[]
Bin9_Salinity=[]
Bin9_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=240 and ds.Lon[ii] <=270:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin9_pH=np.append(Bin9_pH,ds.pHinsitu.values[ii,iii])
                    Bin9_Salinity=np.append(Bin9_Salinity,ds.Salinity.values[ii,iii])
                    Bin9_Depth=np.append(Bin9_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin9_Salinity,Bin9_Depth, c=Bin9_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 9 Salinity vs. Depth',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 9 Salinity vs.Depth.pdf')
# Out:
# <ipython-input-91-fb43f7f6956e>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 10 (270°-300°)

# %%
Bin10_pH=[]
Bin10_Salinity=[]
Bin10_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=270 and ds.Lon[ii] <=300:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin10_pH=np.append(Bin10_pH,ds.pHinsitu.values[ii,iii])
                    Bin10_Salinity=np.append(Bin10_Salinity,ds.Salinity.values[ii,iii])
                    Bin10_Depth=np.append(Bin10_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin10_Salinity,Bin10_Depth, c=Bin10_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 10 Salinity [pss] (270°-300°)',fontweight="bold")
plt.xlim(33,35)
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)
plt.clim(33,35)

#Save figure
plt.savefig('Bin 10 Salinity vs. Depth (270-300).pdf', dpi=600)
# Out:
# <ipython-input-25-3d714e1377e7>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 11 (300°-330°)

# %%
Bin11_pH=[]
Bin11_Salinity=[]
Bin11_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=300 and ds.Lon[ii] <=330:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin11_pH=np.append(Bin11_pH,ds.pHinsitu.values[ii,iii])
                    Bin11_Salinity=np.append(Bin11_Salinity,ds.Salinity.values[ii,iii])
                    Bin11_Depth=np.append(Bin11_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin11_Salinity,Bin11_Depth, c=Bin11_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 11 Salinity vs. Depth',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 11 Salinity vs. Depth.pdf')
# Out:
# <ipython-input-105-484949f02bf2>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()

# %% [markdown]
# ## Bin 12 (330°-360°)

# %%
Bin12_pH=[]
Bin12_Salinity=[]
Bin12_Depth=[]
for i in range(0,len(files)):
    ds=xr.open_dataset(files[i])
    for ii in range (0,len(ds.Lon)):
        if ds.Lon[ii] >=330 and ds.Lon[ii] <=360:
            for iii in range(0,ds.pHinsitu.shape[1]):
                 if ds.pHinsitu.values[ii,iii] >=0 and ds.pHinsitu.values[ii,iii] <=14:
                    Bin12_pH=np.append(Bin12_pH,ds.pHinsitu.values[ii,iii])
                    Bin12_Salinity=np.append(Bin12_Salinity,ds.Salinity.values[ii,iii])
                    Bin12_Depth=np.append(Bin12_Depth,ds.Depth.values[ii,iii])

# %%
#Fig Size
fig=plt.figure(figsize=(10,10))

#Axes, Title font sizes
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=25)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#Plot
plt.scatter(Bin12_Salinity,Bin12_Depth, c=Bin12_Salinity, cmap='RdPu')
ax=plt.axes()
plt.title('Bin 12 Salinity [pss] (330°-360°)',fontweight="bold")
plt.xlabel('Salinity [pss]')
plt.ylabel('Depth [m]')
plt.gca().invert_yaxis()
plt.grid(color='black')

#Plot background Color
ax.set_facecolor("white")

#Colorbar
cbar=plt.colorbar();
cbar.set_label('Salinity [pss]')
cbar.ax.tick_params(labelsize=14)

#Save figure
plt.savefig('Bin 12 Salinity vs. Depth (330-360).pdf', dpi=600)
# Out:
# <ipython-input-16-624dfd450b3e>:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax=plt.axes()
