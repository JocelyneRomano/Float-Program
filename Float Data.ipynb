# %%
import xarray as xr
import glob
import matplotlib.pyplot as plt

# %%
path='/Users/Jocelyne/Desktop/Floats/'
files=glob.glob(path+'*.nc')
files[0]
# Out:
# '/Users/Jocelyne/Desktop/Floats/5904675_HRQC.nc'

# %%
ds = xr.open_dataset(files[0])
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (NPARAMETER: 46, N_LEVELS: 559, N_PROF: 140)
# Dimensions without coordinates: NPARAMETER, N_LEVELS, N_PROF
# Data variables: (12/66)
#     Cruise               |S11 ...
#     Station              (N_PROF) int32 ...
#     Lon                  (N_PROF) float64 ...
#     Lat                  (N_PROF) float64 ...
#     Lat_QF               (N_PROF) |S1 ...
#     Lat_QFA              (N_PROF) float64 ...
#     ...                   ...
#     Type                 |S1 ...
#     mon_day_yr           (N_PROF) |S10 ...
#     hh_mm                (N_PROF) |S5 ...
#     Parameters           (NPARAMETER) |S19 ...
#     JULD                 (N_PROF) datetime64[ns] ...
#     REFERENCE_DATE_TIME  object ...
# Attributes:
#     Comments:  \n//0\n//<Encoding>UTF-8</Encoding>\n//File updated on 05/01/2...

# %% [markdown]
# # Single Float Files

# %%
Float1=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904184_HRQC.nc")
Float2=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904185_HRQC.nc")
Float3=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904186_HRQC.nc")
Float4=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904187_HRQC.nc")
Float5=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904188_HRQC.nc")
Float6=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904396_HRQC.nc")
Float7=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904397_HRQC.nc")
Float8=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904468_HRQC.nc")
Float9=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904469_HRQC.nc")
Float10=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904470_HRQC.nc")
Float11=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904471_HRQC.nc")
Float12=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904472_HRQC.nc")
Float13=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904473_HRQC.nc")
Float15=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904476QC.nc")
Float16=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904477QC.nc")
Float17=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904478QC.nc")
Float18=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904657_HRQC.nc")
Float19=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904658_HRQC.nc")
Float20=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904659_HRQC.nc")
Float21=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904660_HRQC.nc")
Float22=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904661_HRQC.nc")
Float23=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904662_HRQC.nc")
Float24=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904663_HRQC.nc")
Float25=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904670QC.nc")
Float26=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904671QC.nc")
Float27=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904672QC.nc")
Float28=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904673QC.nc")
Float29=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904675_HRQC.nc")
Float30=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904676_HRQC.nc")
Float31=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904677_HRQC.nc")
Float32=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904678_HRQC.nc")
Float33=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904679_HRQC.nc")
Float34=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904682_HRQC.nc")
Float35=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904683_HRQC.nc")
Float36=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904684_HRQC.nc")
Float37=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904686QC.nc")
Float38=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904687QC.nc")
Float39=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904688_HRQC.nc")
Float40=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904693_HRQC.nc")
Float41=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904695_HRQC.nc")
Float42=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904761_HRQC.nc")
Float43=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904763_HRQC.nc")
Float45=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904764_HRQC.nc")
Float46=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904765_HRQC.nc")
Float47=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904766QC.nc")
Float48=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904767QC.nc")
Float49=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904768QC.nc")
Float50=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904841_HRQC.nc")
Float51=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904842_HRQC.nc")
Float52=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904845_HRQC.nc")
Float53=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904846QC.nc")
Float54=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904847QC.nc")
Float55=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904854_HRQC.nc")
Float56=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904855_HRQC.nc")
Float57=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904856_HRQC.nc")
Float58=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904857_HRQC.nc")
Float59=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904858_HRQC.nc")
Float60=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904859_HRQC.nc")
Float61=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904860_HRQC.nc")
Floar62=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904980_HRQC.nc")
Float63=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904981_HRQC.nc")
Float64=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904982_HRQC.nc")
Float64=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904983QC.nc")
Float65=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5904984QC.nc")
Float66=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905069_HRQC.nc")
Float67=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905070_HRQC.nc")
Float68=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905071QC.nc")
Float69=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905072QC.nc")
Float70=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905073QC.nc")
Float71=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905074QC.nc")
Float72=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905075_HRQC.nc")
Float73=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905076_HRQC.nc")
Float74=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905077_HRQC.nc")
Float75=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905078_HRQC.nc")
Float76=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905079_HRQC.nc")
Float77=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905080_HRQC.nc")
Float78=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905099_HRQC.nc")
Float79=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905100_HRQC.nc")
Float80=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905101_HRQC.nc")
Float81=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905102_HRQC.nc")
Float82=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905103_HRQC.nc")
Float83=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905135_HRQC.nc")
Float84=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905366_HRQC.nc")
Float85=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905367_HRQC.nc")
Float86=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905368_HRQC.nc")
Float87=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905369_HRQC.nc")
Float88=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905370_HRQC.nc")
Float89=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905371_HRQC.nc")
Float90=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905372_HRQC.nc")
Float91=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905373_HRQC.nc")
Float92=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905374_HRQC.nc")
Float93=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905375_HRQC.nc")
Float94=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905376_HRQC.nc")
Float95=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905377_HRQC.nc")
Float96=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905378_HRQC.nc")
Float97=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905379_HRQC.nc")
Float98=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905634_HRQC.nc")
Float99=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905635_HRQC.nc")
Float100=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905636_HRQC.nc")
Float101=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905637_HRQC.nc")
Float102=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905638_HRQC.nc")
Float103=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905639_HRQC.nc")
Float104=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905984_HRQC.nc")
Float105=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905991_HRQC.nc")
Float106=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905992_HRQC.nc")
Float107=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905993_HRQC.nc")
Float108=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905994_HRQC.nc")
Float109=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905995_HRQC.nc")
Float110=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905996QC.nc")
Float111=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905997_HRQC.nc")
Float112=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5905998_HRQC.nc")
Float113=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906000_HRQC.nc")
Float114=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906001_HRQC.nc")
Float115=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906002_HRQC.nc")
Float116=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906003_HRQC.nc")
Float117=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906004_HRQC.nc")
Float118=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906005_HRQC.nc")
Float119=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906006_HRQC.nc")
Float120=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906007_HRQC.nc")
Float121=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906008_HRQC.nc")
Float122=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906030_HRQC.nc")
Float123=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906031_HRQC.nc")
Float124=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906032_HRQC.nc")
Float125=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906033_HRQC.nc")
Float126=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906034_HRQC.nc")
Float127=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906206_HRQC.nc")
Float128=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906207_HRQC.nc")
Float129=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906208_HRQC.nc")
Float130=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906209_HRQC.nc")
Float131=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906210_HRQC.nc")
Float132=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906211_HRQC.nc")
Float133=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906212_HRQC.nc")
Float134=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906213_HRQC.nc")
Float135=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906214_HRQC.nc")
Float136=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906215_HRQC.nc")
Float137=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906216_HRQC.nc")
Float138=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906217_HRQC.nc")
Float139=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906220_HRQC.nc")
Float140=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906221_HRQC.nc")
Float141=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906224_HRQC.nc")
Float142=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906225_HRQC.nc")
Float143=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906226_HRQC.nc")
Float144=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906227_HRQC.nc")
Float145=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906228_HRQC.nc")
Float146=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906309QC.nc")
Float147=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906311QC.nc")
Float148=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906313_HRQC.nc")
Float149=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906315_HRQC.nc")
Float150=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906316_HRQC.nc")
Float151=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906317_HRQC.nc")
Float152=xr.open_dataset("/Users/Jocelyne/Desktop/Floats/5906319_HRQC.nc")

# %%
Float123
# Out:
# <xarray.Dataset>
# Dimensions:              (NPARAMETER: 46, N_LEVELS: 559, N_PROF: 74)
# Dimensions without coordinates: NPARAMETER, N_LEVELS, N_PROF
# Data variables: (12/66)
#     Cruise               |S11 ...
#     Station              (N_PROF) int32 ...
#     Lon                  (N_PROF) float64 ...
#     Lat                  (N_PROF) float64 ...
#     Lat_QF               (N_PROF) |S1 ...
#     Lat_QFA              (N_PROF) float64 ...
#     ...                   ...
#     Type                 |S1 ...
#     mon_day_yr           (N_PROF) |S10 ...
#     hh_mm                (N_PROF) |S5 ...
#     Parameters           (NPARAMETER) |S19 ...
#     JULD                 (N_PROF) datetime64[ns] ...
#     REFERENCE_DATE_TIME  object ...
# Attributes:
#     Comments:  \n//0\n//<Encoding>UTF-8</Encoding>\n//File updated on 05/01/2...

# %%
plt.scatter(data1.pHinsitu, data1.Depth, c=data1.Temperature);

# %%
N_PROF=10
datatime=data1.sel(N_PROF=10)

# %%
datatime
# Out:
# <xarray.Dataset>
# Dimensions:              (NPARAMETER: 46, N_LEVELS: 555)
# Dimensions without coordinates: NPARAMETER, N_LEVELS
# Data variables: (12/66)
#     Cruise               |S11 b'    5904184'
#     Station              int32 11
#     Lon                  float64 211.4
#     Lat                  float64 -63.44
#     Lat_QF               |S1 b'4'
#     Lat_QFA              float64 4.0
#     ...                   ...
#     Type                 |S1 b'C'
#     mon_day_yr           |S10 b'07/15/2014'
#     hh_mm                |S5 b'15:43'
#     Parameters           (NPARAMETER) |S19 b'Cruise             ' ... b'REFER...
#     JULD                 datetime64[ns] 2014-07-15T15:42:59.999997184
#     REFERENCE_DATE_TIME  object b'19500101000000'
# Attributes:
#     Comments:  \n//0\n//<Encoding>UTF-8</Encoding>\n//File updated on 05/01/2...

# %%
Lon=('99.47') 
Lat=('-39.451')
Float1.sel(Lat,Lon) #ask joe why this doesn't work
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-0401f7455946> in <module>
#       1 Lon=('99.47')
#       2 Lat=('-39.451')
# ----> 3 data1.sel(Lat,Lon)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/dataset.py in sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2362         DataArray.sel
#    2363         """
# -> 2364         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
#    2365         pos_indexers, new_indexes = remap_label_indexers(
#    2366             self, indexers=indexers, method=method, tolerance=tolerance
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/utils.py in either_dict_or_kwargs(pos_kwargs, kw_kwargs, func_name)
#     281
#     282     if not is_dict_like(pos_kwargs):
# --> 283         raise ValueError(f"the first argument to .{func_name} must be a dictionary")
# ...

# %%
# A graph with 2 x-axes
fig, ax1 = plt.subplots()
ax2 = ax1.twiny() # Create a second axes that shares the same y-axis

color = 'tab:red'
ax1.plot(Float1.Temperature, Float1.Depth, color=color)
ax1.set_ylabel('Depth', color=color)
ax1.tick_params(axis='x', labelcolor=color)

color = 'tab:blue'
ax2.plot(Float1.pHinsitu, Float1.Depth, color=color)
ax2.set_ylabel('pHinsitu', color=color)  
ax2.tick_params(axis='x', labelcolor=color) #How to get one measure of depth throughout the graph? -reverse

# %%
plt.figure(figsize=(8,6))

plt.scatter(MassOSurfSalt.s_an, MassOSurf.t_an, c=MassOSurfDen.I_an, cmap='viridis_r')
plt.xlabel('Salinity');
plt.ylabel('Temperature (°C)')

cbh = plt.colorbar();
cbh.set_label('Density')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-173815037960> in <module>
#       1 plt.figure(figsize=(8,6))
#       2
# ----> 3 plt.scatter(MassOSurfSalt.s_an, MassOSurf.t_an, c=MassOSurfDen.I_an, cmap='viridis_r')
#       4 plt.xlabel('Salinity');
#       5 plt.ylabel('Temperature (°C)')
#
# NameError: name 'MassOSurfSalt' is not defined

# %%
plt.scatter(ds.pHinsitu, ds.Depth);

# %%
Float1=1
while Float1 <= 70:
    plt.plot(ds.Lat)
    Float1 += 1

# %%
Float1=1
if Float1 (ds.Lat >=70 and ds.Lat <=65):
    plt.scatter(ds.Lat)
    Float1 += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8884de1c8b48> in <module>
#       1 Float1=1
# ----> 2 if Float1 (ds.Lat >=70 and ds.Lat <=65):
#       3     plt.scatter(ds.Lat)
#       4     Float1 += 1
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xarray/core/common.py in __bool__(self)
#     127
#     128     def __bool__(self: Any) -> bool:
# --> 129         return bool(self.values)
#     130
#     131     def __float__(self: Any) -> float:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
